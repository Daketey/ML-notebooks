# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import pandas as pd
import numpy as np
import keras
import os
# Out:
# Using TensorFlow backend.

# %%
from keras.utils import to_categorical

# %%
trainset=pd.read_excel(r"C:/Users/KIIT/Dataset/Classification_Dataset/TrainingSet.xlsx" , names =['vale1','vale2','vale3','vale4','vale5','vale6','vale7','vale8','vale9','vale10'])
trainlab=pd.read_excel(r"C:/Users/KIIT/Dataset/Classification_Dataset/Training Label.xlsx" , names = ['labels'])

# %%
trainset
# Out:
#           vale1     vale2     vale3     vale4      vale5     vale6     vale7  \
# 0     -0.132753 -0.163220  0.298510 -0.386726   0.934570 -0.386188 -0.292001
# 1     -0.196359 -0.214179  0.295062 -0.257458   0.937696 -0.357075 -0.319707
# 2     -0.077665 -0.108193  0.374364 -0.218162   0.993907 -0.400560 -0.379472
# 3     -0.099537 -0.132895  0.315553 -0.334031   1.171973 -0.488372 -0.408483
# 4     -0.093664 -0.126818  0.277582 -0.362626   1.325761 -0.446401 -0.309932
# 5     -0.071074 -0.101462  0.300357 -0.290092   1.024788 -0.406208 -0.348910
# 6     -0.069871 -0.111972  0.279140 -0.201363   1.004114 -0.442503 -0.355022
# 7     -0.068963 -0.118867  0.283830 -0.210582   0.929242 -0.374093 -0.325621
# 8     -0.066107 -0.108463  0.281386 -0.209719   0.961061 -0.337995 -0.305571
# 9     -0.088034 -0.098137  0.328374 -0.358000   1.118687 -0.433385 -0.340641
# 10    -0.066518 -0.083205  0.362228 -0.418942   1.005117 -0.387623 -0.319449
# 11    -0.153702 -0.172314  0.339840 -0.227794   0.944249 -0.373320 -0.342752
# 12    -0.101793 -0.133517  0.300235 -0.341706   1.201681 -0.394572 -0.335286
# 13    -0.063981 -0.103824  0.331619 -0.305277   1.120087 -0.462908 -0.390799
# 14    -0.163476 -0.192762  0.347723 -0.246417   0.907059 -0.405028 -0.284336
# 15    -0.187752 -0.220016  0.195856 -0.457633   1.640752 -0.485273 -0.392639
# 16    -0.136028 -0.169536  0.315292 -0.221919   1.076956 -0.375111 -0.357694
# 17    -0.106809 -0.123193  0.359478 -0.394731   1.208131 -0.438959 -0.344762
# 18    -0.066736 -0.077009  0.337990 -0.371382   1.068374 -0.377302 -0.319173
# 19    -0.056999 -0.076866  0.358615 -0.326356   1.052734 -0.385181 -0.312065
# 20    -0.083227 -0.111953  0.337010 -0.316697   1.078108 -0.385813 -0.346768
# 21    -0.188931 -0.217037  0.246500 -0.562579   1.749098 -0.564198 -0.471083
# 22    -0.101457 -0.129740  0.410164 -0.156739   0.937274 -0.405980 -0.322047
# 23    -0.107716 -0.131839  0.363886 -0.260467   1.096096 -0.406936 -0.330760
# 24    -0.109616 -0.133069  0.333967 -0.397598   1.299470 -0.484705 -0.396723
# 25    -0.143791 -0.168539  0.320972 -0.269269   1.030920 -0.431791 -0.386264
# 26    -0.054047 -0.086088  0.387844 -0.281310   0.957850 -0.421434 -0.311563
# 27    -0.067393 -0.084683  0.367638 -0.352168   1.155893 -0.434925 -0.341926
# 28    -0.149425 -0.180366  0.290447 -0.392094   1.626789 -0.591619 -0.460742
# 29    -0.164934 -0.194465  0.334495 -0.212370   0.972565 -0.411916 -0.333929
# ...         ...       ...       ...       ...        ...       ...       ...
# 13    -0.336487  0.169586  0.036757
# 14    -0.301849  0.146223  0.001005
# 15    -0.550662  0.132420 -0.015379
# 16    -0.471369  0.164983  0.035579
# 17    -0.409337  0.106621  0.152076
# 18    -0.380848  0.120669  0.009945
# 19    -0.493221  0.148993  0.056960
# 20    -0.419058  0.208838  0.001460
# 21    -0.400619  0.126096 -0.088983
# 22    -0.423336  0.109257  0.060482
# 23    -0.525543  0.159101  0.069152
# 24    -0.418470  0.182170  0.107683
# 25    -0.376360  0.190150  0.076112
# 26    -0.421685  0.056158  0.162832
# 27    -0.511379  0.165517  0.036403
# 28    -0.425141  0.145668 -0.036741
# 29    -0.301265  0.203633  0.007690
# ...         ...       ...       ...
# 17710  1.221671  0.071264  1.349960
# 17711  0.489034 -0.101622  1.273042
# 17712  1.956256  0.297461 -0.628459
# 17713  1.720961 -0.258126 -0.312380
# 17714  0.682929 -0.171238  0.640702
# 17715  2.413193  0.321548 -0.392494
# 17716  0.946228  0.394155  1.248120
# 17717  2.056877  0.221879 -0.516038
# 17718  2.084306 -0.363114 -0.016709
# 17719  0.976518 -0.087166  1.247053
# 17720  0.636140  0.507417  0.287652
# 17721  0.625474 -0.054445  1.683146
# 17722  2.072303  0.004444 -0.108284
# 17723  2.146476 -1.243901  0.076870
# 17724  0.956440  0.591354  0.570861
# 17725  1.057339  0.466081  0.529739
# 17726  1.976299 -0.398533  0.787815
# 17727  2.541674 -0.250884 -0.681386
# 17728  1.547540  0.367736  0.375711
# 17729  1.990140  0.485458  0.833993
# 17730  2.113689  0.498538 -0.163854
# 17731  1.838133 -0.095786  0.598630
# 17732  1.320530  0.338660  1.133806
# 17733  2.673452 -0.185299  0.858153
# 17734 -0.364815  0.829513  0.786731
# 17735  1.317099  0.113996  0.732888
# 17736  2.319912  0.437959  0.034665
# 17737  1.858046  0.362092 -0.702696
# 17738  2.537614  0.205411 -0.026392
# 17739  1.262169  1.030016  0.653290
#
# [17740 rows x 10 columns]

# %%
trainset.insert(10 ,'labels' , trainlab)

# %%
trainset.shape
# Out:
# (17740, 11)

# %%
trainset = trainset.sample(frac=1)   #df.sample shuffles the dataset, frac=1 means we take whole dataset as sample

# %%
y = trainset.pop('labels').values

# %%
x = trainset.values

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val  = train_test_split(x, y, test_size=0.20, random_state=1) # 0.25 x 0.8 = 0.2

# %%
print((x_train.shape,y_train.shape))                 #Tranning set size
# Out:
# ((14192, 10), (14192,))

# %%
print((x_val.shape,y_val.shape))                    #Validation set size
# Out:
# ((3548, 10), (3548,))

# %%
y = keras.utils.to_categorical(y, 10)
y_train_oh = keras.utils.to_categorical(y_train, 10)
y_val_oh = keras.utils.to_categorical(y_val, 10)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
from keras_utils import reset_tf_session

# %%
s = reset_tf_session
model = Sequential()
model.add(Dense(40,activation='relu',input_shape=(10,)))
model.add(Dense(40,activation='relu'))
model.add(Dense(9,activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 40)                440
# _________________________________________________________________
# dense_8 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_9 (Dense)              (None, 9)                 369
# =================================================================
# Total params: 2,449
# Trainable params: 2,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras_utils

# %%
 model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
x_train.size
# Out:
# 141920

# %%
# Training
history = model.fit(x_train, y_train ,batch_size=32,  epochs=15, validation_data=(x_val, y_val),  callbacks=[keras_utils.TqdmProgressCallback()], verbose=0)
# Out:
# Epoch 1/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 2/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 3/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 4/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 5/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 6/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 7/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 8/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 9/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 10/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 11/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 12/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 13/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 14/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))
# Epoch 15/15
# HBox(children=(IntProgress(value=0, max=14192), HTML(value='')))

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
testset =pd.read_excel(r"C:/Users/KIIT/Dataset/Classification_Dataset/TestingSet.xlsx", names =['vale1','vale2','vale3','vale4','vale5','vale6','vale7','vale8','vale9','vale10'])

# %%
testlab =pd.read_excel(r"C:/Users/KIIT/Dataset/Classification_Dataset/Testing Label.xlsx", names = ['labels' ,'n','n','n','n','n','n'])

# %%
testlab=testlab.drop(columns=testlab.columns[[1,2,3,4,5,6]], axis=1)

# %%
testset.insert(10 ,'labels' , testlab)

# %%
testset = testset.sample(frac=1)   #df.sample shuffles the dataset, frac=1 means we take whole dataset as sample

# %%
y_test = testset.pop('labels').values

# %%
x_test = testset.values

# %%
y_test_oh = keras.utils.to_categorical(y_test, 10)

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict_classes(x_test,batch_size=32)
acc_test = accuracy_score(y_test, y_pred)
# Out:
# 7584/9572 [======================>.......] - ETA:  - ETA:  - ETA: 0s

# %%
print("Test set accuracy: {:.5f}".format(acc_test))
# Out:
# Test set accuracy: 0.94024

# %%
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_test, y_pred)
print('Confusion Matrix\n')
print(confusion)
# Out:
# Confusion Matrix
#
# [[3325    0    0   46    2    0    9    0]
#  [  13 1314    1    7    8  270    0    1]
#  [   0    0 1289    0    0    1    4    0]
#  [  28   10    2  378   30    0   32    0]
#  [   0    0    0    0 1903    0   14    0]
#  [   2    1    0    1    3  274    5    0]
#  [  10    1    2    3   25    1  300    1]
#  [   5    1    2    1    0    6   24  217]]

# %%
xlab = [0,1 , 2 ,3 ,4 ,5 ,6 ,7 ,8]
ylab = [0,1 , 2 ,3 ,4 ,5 ,6 ,7 ,8]
fig = plt.figure()
conf_img = fig.add_subplot(111)
confusion_matrix = conf_img.matshow(confusion , cmap=plt.cm.Blues )
fig.colorbar(confusion_matrix)
conf_img.set_xticklabels(xlab)
conf_img.set_yticklabels(ylab)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8')]

# %%
FP = confusion.sum(axis=0) - np.diag(confusion) 
FN = confusion.sum(axis=1) - np.diag(confusion)
TP = np.diag(confusion)
TN = confusion.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)

sensitivity = TP/(TP+FN)        # Sensitivity

specificty = TN/(TN+FP)         # Specificity

ACC = (TP+TN)/(TP+FP+FN+TN)     # Overall accuracy for each class

# %%
sensitivity
# Out:
# array([0.98314607, 0.81412639, 0.99613601, 0.7875    , 0.99269692,
#        0.95804196, 0.87463557, 0.84765625])

# %%
specificty
# Out:
# array([0.99063005, 0.99836642, 0.99915439, 0.99362077, 0.99111692,
#        0.97006246, 0.99046484, 0.99978532])

# %%
ACC
# Out:
# array([0.98798579, 0.96730046, 0.99874634, 0.98328458, 0.99143335,
#        0.9697033 , 0.98631425, 0.99571667])

# %%
ACC.sum()/8
# Out:
# 0.985060593397409
